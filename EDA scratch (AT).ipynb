# %%
import pandas as pd

# %%
data = pd.read_csv('./data/Data from NOAA_AT.csv')
# Out:
# /Users/akiratakahashi/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (7,9,11,13,15,17,19,21,23,27,33,39,41,43,45,47,49,51,53,55,57,59,61,63,65,67,69,71,73,75,77,79,81,83,85,87,89,91,93,95,97,99,101,103,105,107) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.isnull().sum()
# Out:
# STATION                0
# NAME                   0
# LATITUDE               0
# LONGITUDE              0
# ELEVATION              0
#                    ...
# WV03_ATTRIBUTES    85491
# WV18               85491
# WV18_ATTRIBUTES    85491
# WV20               85413
# WV20_ATTRIBUTES    85413
# Length: 108, dtype: int64

# %%
data.groupby('NAME').describe()
# Out:
#                          LATITUDE                                              \
#                             count      mean           std       min       25%
# NAME
# DUTCH HARBOR, AK US       13970.0  53.89500  1.055194e-11  53.89500  53.89500
# KETCHIKAN AIRPORT, AK US  14098.0  55.35956  9.400814e-12  55.35956  55.35956
# NOME AIRPORT, AK US       15195.0  64.51110  3.225970e-12  64.51110  64.51110
# PRUDHOE BAY, AK US         7121.0  70.25000  0.000000e+00  70.25000  70.25000
# SAND POINT, AK US          4810.0  55.31667  2.700343e-13  55.31667  55.31667
# SEWARD AIRPORT, AK US     15107.0  60.12833  1.441028e-11  60.12833  60.12833
# YAKUTAT AIRPORT, AK US    15192.0  59.51200  1.009714e-11  59.51200  59.51200
#
#                                                        LONGITUDE             \
#                                50%       75%       max     count       mean
# NAME
# DUTCH HARBOR, AK US       53.89500  53.89500  53.89500   13970.0 -166.54330
# ...

# %%
365*40
# Out:
# 14600

# %%
from datetime import date
f_date = date(1980, 1, 1)
l_date = date(2021, 8, 10)
delta = l_date - f_date
print(delta)
# Out:
# 15197 days, 0:00:00

# %%
edit = pd.read_csv('Edit.txt')

# %%
edit.head()
# Out:
#   site_code year month day hour minute second time_decimal value value_std_dev nvalue latitude longitude altitude elevation intake_height qcflag
# 0  BRW 1973 1 1 0 0 0 1973.0 -999.99 -99.99 0 71....
# 1  BRW 1973 1 2 0 0 0 1973.0027397260274 -999.99 ...
# 2  BRW 1973 1 3 0 0 0 1973.0054794520547 -999.99 ...
# 3  BRW 1973 1 4 0 0 0 1973.0082191780823 -999.99 ...
# 4  BRW 1973 1 5 0 0 0 1973.0109589041097 -999.99 ...

# %%
edit.dtypes
# Out:
# site_code year month day hour minute second time_decimal value value_std_dev nvalue latitude longitude altitude elevation intake_height qcflag    object
# dtype: object

# %%
edit = edit['site_code year month day hour minute second time_decimal value value_std_dev nvalue latitude longitude altitude elevation intake_height qcflag'].str.split(' ', expand=True)

# %%
column_names = ['site_code', 'year', 'month', 'day', 'hour', 'minute', 'second', 'time_decimal', 'value', 'value_std_dev', 'nvalue', 'latitude', 'longitude', 'altitude', 'elevation', 'intake_height', 'qcflag']

# %%
edit.columns = column_names

# %%
edit
# Out:
#       site_code  year month day hour minute second        time_decimal  \
# 0           BRW  1973     1   1    0      0      0              1973.0
# 1           BRW  1973     1   2    0      0      0  1973.0027397260274
# 2           BRW  1973     1   3    0      0      0  1973.0054794520547
# 3           BRW  1973     1   4    0      0      0  1973.0082191780823
# 4           BRW  1973     1   5    0      0      0  1973.0109589041097
# ...         ...   ...   ...  ..  ...    ...    ...                 ...
# 17527       BRW  2020    12  27    0      0      0  2020.9863387978141
# 17528       BRW  2020    12  28    0      0      0  2020.9890710382513
# 17529       BRW  2020    12  29    0      0      0  2020.9918032786886
# 17530       BRW  2020    12  30    0      0      0  2020.9945355191257
# 17531       BRW  2020    12  31    0      0      0  2020.9972677595629
#
#          value value_std_dev nvalue latitude longitude altitude elevation  \
# ...

# %%
edit['day'].replace('1', '01', inplace=True)
edit['day'].replace('2', '02', inplace=True)
edit['day'].replace('3', '03', inplace=True)
edit['day'].replace('4', '04', inplace=True)
edit['day'].replace('5', '05', inplace=True)
edit['day'].replace('6', '06', inplace=True)
edit['day'].replace('7', '07', inplace=True)
edit['day'].replace('8', '08', inplace=True)
edit['day'].replace('9', '09', inplace=True)

edit['month'].replace('1', '01', inplace=True)
edit['month'].replace('2', '02', inplace=True)
edit['month'].replace('3', '03', inplace=True)
edit['month'].replace('4', '04', inplace=True)
edit['month'].replace('5', '05', inplace=True)
edit['month'].replace('6', '06', inplace=True)
edit['month'].replace('7', '07', inplace=True)
edit['month'].replace('8', '08', inplace=True)
edit['month'].replace('9', '09', inplace=True)

# %%
edit['year-month-day'] = edit['year'] + '-' + edit['month'] + '-' + edit['day']

# %%
edit.head()
# Out:
#   site_code  year month day hour minute second        time_decimal    value  \
# 0       BRW  1973    01  01    0      0      0              1973.0  -999.99
# 1       BRW  1973    01  02    0      0      0  1973.0027397260274  -999.99
# 2       BRW  1973    01  03    0      0      0  1973.0054794520547  -999.99
# 3       BRW  1973    01  04    0      0      0  1973.0082191780823  -999.99
# 4       BRW  1973    01  05    0      0      0  1973.0109589041097  -999.99
#
#   value_std_dev nvalue latitude longitude altitude elevation intake_height  \
# 0        -99.99      0   71.323  -156.611     27.0      11.0          16.0
# 1        -99.99      0   71.323  -156.611     27.0      11.0          16.0
# 2        -99.99      0   71.323  -156.611     27.0      11.0          16.0
# 3        -99.99      0   71.323  -156.611     27.0      11.0          16.0
# 4        -99.99      0   71.323  -156.611     27.0      11.0          16.0
#
#   qcflag year-month-day
# 0    *..     1973-01-01
# ...

# %%
edit.drop(columns=['year', 'month', 'day', 'hour', 'minute', 'second'], inplace=True)

# %%
edit
# Out:
#       site_code        time_decimal    value value_std_dev nvalue latitude  \
# 0           BRW              1973.0  -999.99        -99.99      0   71.323
# 1           BRW  1973.0027397260274  -999.99        -99.99      0   71.323
# 2           BRW  1973.0054794520547  -999.99        -99.99      0   71.323
# 3           BRW  1973.0082191780823  -999.99        -99.99      0   71.323
# 4           BRW  1973.0109589041097  -999.99        -99.99      0   71.323
# ...         ...                 ...      ...           ...    ...      ...
# 17527       BRW  2020.9863387978141   419.22           0.1     17   71.323
# 17528       BRW  2020.9890710382513   418.67          0.21     24   71.323
# 17529       BRW  2020.9918032786886   418.88          0.07     24   71.323
# 17530       BRW  2020.9945355191257   418.92          0.06     24   71.323
# 17531       BRW  2020.9972677595629    418.9          0.06     24   71.323
#
# ...

# %%
data.head()
# Out:
#        STATION                 NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USW00026617  NOME AIRPORT, AK US   64.5111    -165.44        4.0
# 1  USW00026617  NOME AIRPORT, AK US   64.5111    -165.44        4.0
# 2  USW00026617  NOME AIRPORT, AK US   64.5111    -165.44        4.0
# 3  USW00026617  NOME AIRPORT, AK US   64.5111    -165.44        4.0
# 4  USW00026617  NOME AIRPORT, AK US   64.5111    -165.44        4.0
#
#          DATE   ACMH ACMH_ATTRIBUTES   ACSH ACSH_ATTRIBUTES  ...  WT22  \
# 0  1980-01-01   20.0             ,,X   50.0             ,,X  ...   NaN
# 1  1980-01-02   50.0             ,,X   90.0             ,,X  ...   NaN
# 2  1980-01-03   40.0             ,,X   60.0             ,,X  ...   NaN
# 3  1980-01-04  100.0             ,,X  100.0             ,,X  ...   NaN
# 4  1980-01-05  100.0             ,,X  100.0             ,,X  ...   NaN
#
#   WT22_ATTRIBUTES  WV01 WV01_ATTRIBUTES  WV03 WV03_ATTRIBUTES  WV18  \
# ...

# %%
edit.merge(data, left_on = edit['year-month-day'], right_on = data['DATE'])
# Out:
#             key_0 site_code        time_decimal   value value_std_dev nvalue  \
# 0      1980-01-01       BRW              1980.0  341.38          0.08      2
# 1      1980-01-01       BRW              1980.0  341.38          0.08      2
# 2      1980-01-01       BRW              1980.0  341.38          0.08      2
# 3      1980-01-01       BRW              1980.0  341.38          0.08      2
# 4      1980-01-01       BRW              1980.0  341.38          0.08      2
# ...           ...       ...                 ...     ...           ...    ...
# 84402  2020-12-31       BRW  2020.9972677595629   418.9          0.06     24
# 84403  2020-12-31       BRW  2020.9972677595629   418.9          0.06     24
# 84404  2020-12-31       BRW  2020.9972677595629   418.9          0.06     24
# 84405  2020-12-31       BRW  2020.9972677595629   418.9          0.06     24
# 84406  2020-12-31       BRW  2020.9972677595629   418.9          0.06     24
#
# ...

# %%
edit
# Out:
#       site_code        time_decimal    value value_std_dev nvalue latitude  \
# 0           BRW              1973.0  -999.99        -99.99      0   71.323
# 1           BRW  1973.0027397260274  -999.99        -99.99      0   71.323
# 2           BRW  1973.0054794520547  -999.99        -99.99      0   71.323
# 3           BRW  1973.0082191780823  -999.99        -99.99      0   71.323
# 4           BRW  1973.0109589041097  -999.99        -99.99      0   71.323
# ...         ...                 ...      ...           ...    ...      ...
# 17527       BRW  2020.9863387978141   419.22           0.1     17   71.323
# 17528       BRW  2020.9890710382513   418.67          0.21     24   71.323
# 17529       BRW  2020.9918032786886   418.88          0.07     24   71.323
# 17530       BRW  2020.9945355191257   418.92          0.06     24   71.323
# 17531       BRW  2020.9972677595629    418.9          0.06     24   71.323
#
# ...
